# %%
import os
import pandas as pd
import calendar
from datetime import datetime
import xlsxwriter

excel_file_path = os.path.expanduser("~/Documents/data_db-in-documents/training_calendar_2025_full.xlsx")

# 读取训练数据
df = pd.read_csv(os.path.expanduser("~/Documents/data_db-in-documents/gym_exercise_sessions_202507110825.csv"))
df["fmt_exercise_date"] = pd.to_datetime(df["fmt_exercise_date"])

# %%
# 映射动作→身体部位（可自行补全）
movement_to_bodypart = {
    "CRUNCH": "ABS",
    "CURL": "ARM",
    "LEG_PRESS": "LEG",
    "FARMERS_WALK": "GRIP",
    "CHEST_PRESS_WITH_BAND": "CHEST",
    "DUMBBELL_BICEPS_CURL": "ARM",
    "BENCH_PRESS": "CHEST",
    "SHOULDER_PRESS": "SHOULDER",
    "DIAMOND_PUSH_UP": "TRICEPS",
    "BENCH_DIP": "TRICEPS",
}

# %%
# 聚合每天每个动作的训练总量
agg_info = (
    df.groupby(["fmt_exercise_date", "fmt_movement"])
    .agg({"weight": "sum", "repetition_count": "sum"})
    .reset_index()
)
agg_info
# Out:
#     fmt_exercise_date             fmt_movement    weight  repetition_count
# 0          2024-11-08                BAR_HOLDS   35000.0               100
# 1          2024-11-11              BARBELL_ROW   22000.0                43
# 2          2024-11-11            LEG_ADDUCTION  161000.0                74
# 3          2024-11-11           SHOULDER_PRESS  112000.0                54
# 4          2024-11-11  WEIGHTED_LEG_EXTENSIONS  154000.0                32
# ..                ...                      ...       ...               ...
# 561        2025-07-10  CABLE_INTERNAL_ROTATION   22500.0                24
# 562        2025-07-10       CABLE_ROW_STANDING  240000.0                33
# 563        2025-07-10      CROSSED_ARMS_SIT_UP       0.0                30
# 564        2025-07-10         SEATED_CABLE_ROW  434000.0                32
# 565        2025-07-10             SEATED_LEG_U       0.0                30
#
# [566 rows x 4 columns]

# %%
movement_dates = df.groupby("fmt_movement")["fmt_exercise_date"].apply(lambda x: sorted(set(x))).to_dict()
latest_date = df["fmt_exercise_date"].max()
movement_dates
# Out:
# {'BARBELL_BENCH_PRESS': [Timestamp('2025-04-11 00:00:00'),
#   Timestamp('2025-04-16 00:00:00')],
#  'BARBELL_BULGARIAN_SPLIT_SQUAT': [Timestamp('2025-07-08 00:00:00')],
#  'BARBELL_DEADLIFT': [Timestamp('2025-01-26 00:00:00'),
#   Timestamp('2025-01-29 00:00:00'),
#   Timestamp('2025-01-30 00:00:00'),
#   Timestamp('2025-02-04 00:00:00'),
#   Timestamp('2025-02-08 00:00:00'),
#   Timestamp('2025-02-12 00:00:00'),
#   Timestamp('2025-04-18 00:00:00')],
#  'BARBELL_ROW': [Timestamp('2024-11-11 00:00:00'),
#   Timestamp('2025-01-30 00:00:00')],
#  'BARBELL_SHOULDER_PRESS': [Timestamp('2025-02-08 00:00:00')],
#  'BAR_HOLDS': [Timestamp('2024-11-08 00:00:00'),
#   Timestamp('2025-02-18 00:00:00')],
#  'BENCH_DIP': [Timestamp('2025-04-29 00:00:00'),
#   Timestamp('2025-05-03 00:00:00')],
#  'BENCH_PRESS': [Timestamp('2025-02-12 00:00:00'),
#   Timestamp('2025-02-21 00:00:00'),
#   Timestamp('2025-02-26 00:00:00'),
#   Timestamp('2025-02-28 00:00:00'),
#   Timestamp('2025-03-11 00:00:00'),
#   Timestamp('2025-03-14 00:00:00'),
#   Timestamp('2025-03-17 00:00:00'),
#   Timestamp('2025-03-19 00:00:00'),
#   Timestamp('2025-03-25 00:00:00'),
#   Timestamp('2025-03-28 00:00:00'),
#   Timestamp('2025-03-31 00:00:00'),
#   Timestamp('2025-04-03 00:00:00'),
#   Timestamp('2025-04-08 00:00:00'),
#   Timestamp('2025-04-23 00:00:00'),
#   Timestamp('2025-06-06 00:00:00'),
#   Timestamp('2025-06-11 00:00:00')],
#  'BENT_OVER_ROW_WITH_DUMBELL': [Timestamp('2025-02-10 00:00:00'),
#   Timestamp('2025-02-19 00:00:00'),
#   Timestamp('2025-02-21 00:00:00'),
#   Timestamp('2025-02-28 00:00:00'),
#   Timestamp('2025-03-11 00:00:00'),
#   Timestamp('2025-03-17 00:00:00'),
#   Timestamp('2025-03-19 00:00:00'),
#   Timestamp('2025-03-25 00:00:00'),
#   Timestamp('2025-04-01 00:00:00'),
#   Timestamp('2025-04-03 00:00:00'),
#   Timestamp('2025-04-07 00:00:00'),
#   Timestamp('2025-04-09 00:00:00'),
#   Timestamp('2025-04-22 00:00:00'),
#   Timestamp('2025-05-26 00:00:00'),
#   Timestamp('2025-05-28 00:00:00'),
#   Timestamp('2025-06-10 00:00:00')],
#  'CABLE_BICEPS_CURL': [Timestamp('2025-06-06 00:00:00'),
#   Timestamp('2025-07-02 00:00:00')],
#  'CABLE_CRUNCH': [Timestamp('2025-07-10 00:00:00')],
#  'CABLE_EXTERNAL_ROTATION': [Timestamp('2025-07-10 00:00:00')],
#  'CABLE_INTERNAL_ROTATION': [Timestamp('2025-07-10 00:00:00')],
#  'CABLE_OVERHEAD_TRICEPS_EXTENSION': [Timestamp('2025-06-17 00:00:00'),
#   Timestamp('2025-06-19 00:00:00'),
#   Timestamp('2025-06-23 00:00:00'),
#   Timestamp('2025-06-27 00:00:00'),
#   Timestamp('2025-06-30 00:00:00'),
#   Timestamp('2025-07-02 00:00:00'),
#   Timestamp('2025-07-04 00:00:00'),
#   Timestamp('2025-07-07 00:00:00'),
#   Timestamp('2025-07-09 00:00:00')],
#  'CABLE_ROW_STANDING': [Timestamp('2024-12-02 00:00:00'),
#   Timestamp('2024-12-04 00:00:00'),
#   Timestamp('2024-12-16 00:00:00'),
#   Timestamp('2024-12-27 00:00:00'),
#   Timestamp('2024-12-30 00:00:00'),
#   Timestamp('2024-12-31 00:00:00'),
#   Timestamp('2025-01-03 00:00:00'),
#   Timestamp('2025-01-08 00:00:00'),
#   Timestamp('2025-01-10 00:00:00'),
#   Timestamp('2025-01-13 00:00:00'),
#   Timestamp('2025-01-15 00:00:00'),
#   Timestamp('2025-01-17 00:00:00'),
#   Timestamp('2025-01-20 00:00:00'),
#   Timestamp('2025-01-22 00:00:00'),
#   Timestamp('2025-01-24 00:00:00'),
#   Timestamp('2025-02-08 00:00:00'),
#   Timestamp('2025-03-05 00:00:00'),
#   Timestamp('2025-03-07 00:00:00'),
#   Timestamp('2025-07-04 00:00:00'),
#   Timestamp('2025-07-08 00:00:00'),
#   Timestamp('2025-07-10 00:00:00')],
#  'CALF_RAISE': [Timestamp('2025-02-11 00:00:00'),
#   Timestamp('2025-04-22 00:00:00'),
#   Timestamp('2025-05-27 00:00:00'),
#   Timestamp('2025-05-29 00:00:00'),
#   Timestamp('2025-06-06 00:00:00'),
#   Timestamp('2025-06-11 00:00:00'),
#   Timestamp('2025-06-16 00:00:00'),
#   Timestamp('2025-06-20 00:00:00'),
#   Timestamp('2025-07-01 00:00:00'),
#   Timestamp('2025-07-07 00:00:00')],
#  'CHEST_PRESS_WITH_BAND': [Timestamp('2024-11-12 00:00:00'),
#   Timestamp('2024-11-14 00:00:00'),
#   Timestamp('2024-11-19 00:00:00'),
#   Timestamp('2024-11-21 00:00:00'),
#   Timestamp('2024-11-26 00:00:00'),
#   Timestamp('2024-11-28 00:00:00'),
#   Timestamp('2024-12-03 00:00:00'),
#   Timestamp('2024-12-05 00:00:00'),
#   Timestamp('2024-12-12 00:00:00'),
#   Timestamp('2024-12-17 00:00:00'),
#   Timestamp('2024-12-26 00:00:00'),
#   Timestamp('2024-12-31 00:00:00'),
#   Timestamp('2025-01-02 00:00:00'),
#   Timestamp('2025-01-07 00:00:00'),
#   Timestamp('2025-01-09 00:00:00'),
#   Timestamp('2025-01-13 00:00:00'),
#   Timestamp('2025-01-15 00:00:00'),
#   Timestamp('2025-01-17 00:00:00'),
#   Timestamp('2025-01-20 00:00:00'),
#   Timestamp('2025-01-22 00:00:00'),
#   Timestamp('2025-01-24 00:00:00'),
#   Timestamp('2025-01-30 00:00:00'),
#   Timestamp('2025-02-10 00:00:00'),
#   Timestamp('2025-02-11 00:00:00'),
#   Timestamp('2025-02-18 00:00:00'),
#   Timestamp('2025-03-05 00:00:00'),
#   Timestamp('2025-03-07 00:00:00'),
#   Timestamp('2025-03-11 00:00:00'),
#   Timestamp('2025-03-25 00:00:00'),
#   Timestamp('2025-04-08 00:00:00'),
#   Timestamp('2025-04-11 00:00:00'),
#   Timestamp('2025-06-16 00:00:00'),
#   Timestamp('2025-06-23 00:00:00'),
#   Timestamp('2025-07-02 00:00:00'),
#   Timestamp('2025-07-04 00:00:00'),
#   Timestamp('2025-07-07 00:00:00'),
#   Timestamp('2025-07-09 00:00:00')],
#  'CROSSED_ARMS_SIT_UP': [Timestamp('2025-07-08 00:00:00'),
#   Timestamp('2025-07-10 00:00:00')],
#  'CURL': [Timestamp('2024-11-14 00:00:00'),
#   Timestamp('2024-11-19 00:00:00'),
#   Timestamp('2024-11-21 00:00:00'),
#   Timestamp('2024-11-27 00:00:00'),
#   Timestamp('2024-12-03 00:00:00'),
#   Timestamp('2024-12-16 00:00:00'),
#   Timestamp('2024-12-31 00:00:00'),
#   Timestamp('2025-01-02 00:00:00'),
#   Timestamp('2025-01-09 00:00:00'),
#   Timestamp('2025-01-10 00:00:00'),
#   Timestamp('2025-01-13 00:00:00'),
#   Timestamp('2025-01-29 00:00:00'),
#   Timestamp('2025-04-24 00:00:00'),
#   Timestamp('2025-05-26 00:00:00'),
#   Timestamp('2025-06-09 00:00:00')],
#  'DEADLIFT': [Timestamp('2025-01-07 00:00:00'),
#   Timestamp('2025-01-10 00:00:00'),
#   Timestamp('2025-01-13 00:00:00'),
#   Timestamp('2025-01-15 00:00:00'),
#   Timestamp('2025-01-17 00:00:00'),
#   Timestamp('2025-01-20 00:00:00'),
#   Timestamp('2025-01-29 00:00:00'),
#   Timestamp('2025-02-01 00:00:00')],
#  'DIAMOND_PUSH_UP': [Timestamp('2025-04-30 00:00:00'),
#   Timestamp('2025-05-07 00:00:00'),
#   Timestamp('2025-05-09 00:00:00'),
#   Timestamp('2025-05-20 00:00:00'),
#   Timestamp('2025-05-24 00:00:00')],
#  'DUMBBELL_BENCH_PRESS': [Timestamp('2025-02-18 00:00:00'),
#   Timestamp('2025-05-29 00:00:00'),
#   Timestamp('2025-06-16 00:00:00'),
#   Timestamp('2025-06-18 00:00:00'),
#   Timestamp('2025-06-23 00:00:00'),
#   Timestamp('2025-06-25 00:00:00'),
#   Timestamp('2025-06-27 00:00:00'),
#   Timestamp('2025-06-30 00:00:00'),
#   Timestamp('2025-07-07 00:00:00'),
#   Timestamp('2025-07-09 00:00:00')],
#  'DUMBBELL_BICEPS_CURL': [Timestamp('2025-06-06 00:00:00'),
#   Timestamp('2025-06-20 00:00:00'),
#   Timestamp('2025-06-30 00:00:00'),
#   Timestamp('2025-07-04 00:00:00'),
#   Timestamp('2025-07-07 00:00:00'),
#   Timestamp('2025-07-09 00:00:00')],
#  'DUMBBELL_BULGARIAN_SPLIT_SQUAT': [Timestamp('2025-04-28 00:00:00'),
#   Timestamp('2025-05-10 00:00:00')],
#  'DUMBBELL_DEADLIFT': [Timestamp('2025-02-10 00:00:00')],
#  'DUMBBELL_FLYE': [Timestamp('2025-02-09 00:00:00'),
#   Timestamp('2025-02-11 00:00:00')],
#  'DUMBBELL_LATERAL_RAISE': [Timestamp('2025-05-28 00:00:00'),
#   Timestamp('2025-06-04 00:00:00'),
#   Timestamp('2025-06-17 00:00:00'),
#   Timestamp('2025-07-09 00:00:00')],
#  'DUMBBELL_REVERSE_WRIST_CURL': [Timestamp('2025-04-20 00:00:00'),
#   Timestamp('2025-05-30 00:00:00')],
#  'DUMBBELL_SHOULDER_PRESS': [Timestamp('2025-02-10 00:00:00'),
#   Timestamp('2025-05-27 00:00:00'),
#   Timestamp('2025-06-04 00:00:00')],
#  'DUMBBELL_SHRUG': [Timestamp('2025-05-28 00:00:00'),
#   Timestamp('2025-06-04 00:00:00'),
#   Timestamp('2025-06-06 00:00:00'),
#   Timestamp('2025-06-12 00:00:00')],
#  'DUMBBELL_WRIST_CURL': [Timestamp('2025-04-20 00:00:00'),
#   Timestamp('2025-05-30 00:00:00')],
#  'FARMERS_WALK': [Timestamp('2025-04-07 00:00:00'),
#   Timestamp('2025-04-09 00:00:00'),
#   Timestamp('2025-04-11 00:00:00'),
#   Timestamp('2025-04-17 00:00:00'),
#   Timestamp('2025-04-20 00:00:00'),
#   Timestamp('2025-04-22 00:00:00'),
#   Timestamp('2025-05-25 00:00:00'),
#   Timestamp('2025-05-27 00:00:00'),
#   Timestamp('2025-05-30 00:00:00'),
#   Timestamp('2025-06-06 00:00:00'),
#   Timestamp('2025-06-10 00:00:00'),
#   Timestamp('2025-06-12 00:00:00'),
#   Timestamp('2025-06-17 00:00:00'),
#   Timestamp('2025-06-20 00:00:00'),
#   Timestamp('2025-06-24 00:00:00'),
#   Timestamp('2025-06-26 00:00:00'),
#   Timestamp('2025-06-30 00:00:00'),
#   Timestamp('2025-07-02 00:00:00'),
#   Timestamp('2025-07-04 00:00:00'),
#   Timestamp('2025-07-09 00:00:00')],
#  'FLYE': [Timestamp('2024-11-12 00:00:00'),
#   Timestamp('2024-11-14 00:00:00'),
#   Timestamp('2024-11-19 00:00:00'),
#   Timestamp('2024-11-21 00:00:00'),
#   Timestamp('2024-11-26 00:00:00'),
#   Timestamp('2024-11-28 00:00:00'),
#   Timestamp('2024-12-03 00:00:00'),
#   Timestamp('2024-12-05 00:00:00'),
#   Timestamp('2024-12-12 00:00:00'),
#   Timestamp('2024-12-17 00:00:00'),
#   Timestamp('2024-12-26 00:00:00'),
#   Timestamp('2024-12-31 00:00:00'),
#   Timestamp('2025-01-02 00:00:00'),
#   Timestamp('2025-01-07 00:00:00'),
#   Timestamp('2025-01-09 00:00:00'),
#   Timestamp('2025-01-13 00:00:00'),
#   Timestamp('2025-01-15 00:00:00'),
#   Timestamp('2025-01-17 00:00:00'),
#   Timestamp('2025-01-20 00:00:00'),
#   Timestamp('2025-01-22 00:00:00'),
#   Timestamp('2025-01-24 00:00:00'),
#   Timestamp('2025-02-18 00:00:00'),
#   Timestamp('2025-02-26 00:00:00'),
#   Timestamp('2025-07-02 00:00:00')],
#  'INCLINE_DUMBBELL_BENCH_PRESS': [Timestamp('2025-05-25 00:00:00')],
#  'INCLINE_DUMBBELL_BICEPS_CURL': [Timestamp('2025-04-18 00:00:00'),
#   Timestamp('2025-07-07 00:00:00')],
#  'INCLINE_DUMBBELL_FLYE': [Timestamp('2025-02-12 00:00:00')],
#  'INCLINE_REVERSE_FLYE': [Timestamp('2024-11-15 00:00:00'),
#   Timestamp('2024-11-20 00:00:00'),
#   Timestamp('2024-11-22 00:00:00'),
#   Timestamp('2024-11-25 00:00:00'),
#   Timestamp('2024-11-27 00:00:00'),
#   Timestamp('2024-11-29 00:00:00'),
#   Timestamp('2024-12-02 00:00:00'),
#   Timestamp('2024-12-04 00:00:00'),
#   Timestamp('2024-12-06 00:00:00'),
#   Timestamp('2024-12-13 00:00:00'),
#   Timestamp('2024-12-16 00:00:00'),
#   Timestamp('2024-12-18 00:00:00'),
#   Timestamp('2024-12-25 00:00:00'),
#   Timestamp('2024-12-27 00:00:00'),
#   Timestamp('2024-12-30 00:00:00'),
#   Timestamp('2024-12-31 00:00:00'),
#   Timestamp('2025-01-03 00:00:00'),
#   Timestamp('2025-01-06 00:00:00'),
#   Timestamp('2025-01-08 00:00:00'),
#   Timestamp('2025-01-10 00:00:00'),
#   Timestamp('2025-01-13 00:00:00'),
#   Timestamp('2025-01-15 00:00:00'),
#   Timestamp('2025-01-17 00:00:00'),
#   Timestamp('2025-01-20 00:00:00'),
#   Timestamp('2025-01-22 00:00:00'),
#   Timestamp('2025-01-24 00:00:00'),
#   Timestamp('2025-02-19 00:00:00'),
#   Timestamp('2025-02-21 00:00:00'),
#   Timestamp('2025-03-05 00:00:00'),
#   Timestamp('2025-03-07 00:00:00'),
#   Timestamp('2025-03-11 00:00:00'),
#   Timestamp('2025-03-17 00:00:00'),
#   Timestamp('2025-03-25 00:00:00'),
#   Timestamp('2025-04-07 00:00:00'),
#   Timestamp('2025-04-09 00:00:00')],
#  'LATERAL_RAISE': [Timestamp('2025-01-03 00:00:00'),
#   Timestamp('2025-01-06 00:00:00'),
#   Timestamp('2025-01-08 00:00:00'),
#   Timestamp('2025-01-10 00:00:00'),
#   Timestamp('2025-01-13 00:00:00'),
#   Timestamp('2025-01-15 00:00:00'),
#   Timestamp('2025-01-17 00:00:00'),
#   Timestamp('2025-01-20 00:00:00'),
#   Timestamp('2025-01-22 00:00:00'),
#   Timestamp('2025-01-24 00:00:00'),
#   Timestamp('2025-01-29 00:00:00'),
#   Timestamp('2025-01-30 00:00:00'),
#   Timestamp('2025-02-08 00:00:00'),
#   Timestamp('2025-02-10 00:00:00'),
#   Timestamp('2025-02-12 00:00:00'),
#   Timestamp('2025-02-18 00:00:00'),
#   Timestamp('2025-02-19 00:00:00'),
#   Timestamp('2025-02-21 00:00:00'),
#   Timestamp('2025-02-26 00:00:00'),
#   Timestamp('2025-03-14 00:00:00'),
#   Timestamp('2025-03-17 00:00:00'),
#   Timestamp('2025-03-28 00:00:00'),
#   Timestamp('2025-04-01 00:00:00'),
#   Timestamp('2025-04-03 00:00:00'),
#   Timestamp('2025-04-08 00:00:00'),
#   Timestamp('2025-04-17 00:00:00'),
#   Timestamp('2025-06-12 00:00:00'),
#   Timestamp('2025-06-25 00:00:00')],
#  'LEG_ABDUCTION': [Timestamp('2025-01-26 00:00:00'),
#   Timestamp('2025-01-29 00:00:00'),
#   Timestamp('2025-02-01 00:00:00'),
#   Timestamp('2025-02-19 00:00:00'),
#   Timestamp('2025-06-09 00:00:00')],
#  'LEG_ADDUCTION': [Timestamp('2024-11-11 00:00:00'),
#   Timestamp('2024-11-13 00:00:00'),
#   Timestamp('2024-11-15 00:00:00'),
#   Timestamp('2024-11-18 00:00:00'),
#   Timestamp('2024-11-20 00:00:00'),
#   Timestamp('2024-11-22 00:00:00'),
#   Timestamp('2024-11-25 00:00:00'),
#   Timestamp('2024-11-27 00:00:00'),
#   Timestamp('2024-11-29 00:00:00'),
#   Timestamp('2024-12-02 00:00:00'),
#   Timestamp('2024-12-04 00:00:00'),
#   Timestamp('2024-12-06 00:00:00'),
#   Timestamp('2024-12-13 00:00:00'),
#   Timestamp('2024-12-16 00:00:00'),
#   Timestamp('2024-12-25 00:00:00'),
#   Timestamp('2024-12-27 00:00:00'),
#   Timestamp('2024-12-31 00:00:00'),
#   Timestamp('2025-01-03 00:00:00'),
#   Timestamp('2025-01-06 00:00:00'),
#   Timestamp('2025-01-10 00:00:00'),
#   Timestamp('2025-01-13 00:00:00'),
#   Timestamp('2025-01-15 00:00:00'),
#   Timestamp('2025-01-17 00:00:00'),
#   Timestamp('2025-01-20 00:00:00'),
#   Timestamp('2025-02-18 00:00:00')],
#  'LEG_EXTENSION': [Timestamp('2024-11-28 00:00:00'),
#   Timestamp('2025-01-02 00:00:00'),
#   Timestamp('2025-01-07 00:00:00'),
#   Timestamp('2025-01-09 00:00:00'),
#   Timestamp('2025-01-13 00:00:00'),
#   Timestamp('2025-01-17 00:00:00'),
#   Timestamp('2025-01-20 00:00:00')],
#  'LEG_PRESS': [Timestamp('2025-01-22 00:00:00'),
#   Timestamp('2025-01-24 00:00:00'),
#   Timestamp('2025-02-18 00:00:00'),
#   Timestamp('2025-02-26 00:00:00'),
#   Timestamp('2025-02-28 00:00:00'),
#   Timestamp('2025-03-05 00:00:00'),
#   Timestamp('2025-03-07 00:00:00'),
#   Timestamp('2025-05-25 00:00:00'),
#   Timestamp('2025-05-29 00:00:00'),
#   Timestamp('2025-06-04 00:00:00'),
#   Timestamp('2025-06-10 00:00:00'),
#   Timestamp('2025-06-13 00:00:00'),
#   Timestamp('2025-06-18 00:00:00'),
#   Timestamp('2025-06-24 00:00:00'),
#   Timestamp('2025-06-27 00:00:00'),
#   Timestamp('2025-07-01 00:00:00'),
#   Timestamp('2025-07-04 00:00:00'),
#   Timestamp('2025-07-07 00:00:00'),
#   Timestamp('2025-07-09 00:00:00')],
#  'LEG_RAISE': [Timestamp('2025-01-02 00:00:00')],
#  'ONE_ARM_BENT_OVER_ROW': [Timestamp('2025-02-09 00:00:00')],
#  'ONE_ARM_CABLE_LATERAL_RAISE': [Timestamp('2025-06-25 00:00:00'),
#   Timestamp('2025-06-27 00:00:00'),
#   Timestamp('2025-07-01 00:00:00'),
#   Timestamp('2025-07-04 00:00:00'),
#   Timestamp('2025-07-07 00:00:00'),
#   Timestamp('2025-07-09 00:00:00')],
#  'PULL_UP': [Timestamp('2025-02-12 00:00:00')],
#  'PUSH_UP': [Timestamp('2025-04-29 00:00:00')],
#  'REVERSE_CRUNCH_ON_A_BENCH': [Timestamp('2025-01-02 00:00:00'),
#   Timestamp('2025-01-03 00:00:00'),
#   Timestamp('2025-01-06 00:00:00'),
#   Timestamp('2025-01-07 00:00:00'),
#   Timestamp('2025-01-08 00:00:00'),
#   Timestamp('2025-01-09 00:00:00'),
#   Timestamp('2025-01-13 00:00:00'),
#   Timestamp('2025-01-15 00:00:00'),
#   Timestamp('2025-01-17 00:00:00')],
#  'ROPE_PRESSDOWN': [Timestamp('2024-12-12 00:00:00'),
#   Timestamp('2025-06-09 00:00:00'),
#   Timestamp('2025-06-13 00:00:00')],
#  'ROW': [Timestamp('2024-11-22 00:00:00'),
#   Timestamp('2024-11-25 00:00:00'),
#   Timestamp('2024-11-27 00:00:00'),
#   Timestamp('2024-11-29 00:00:00'),
#   Timestamp('2024-12-06 00:00:00'),
#   Timestamp('2024-12-13 00:00:00'),
#   Timestamp('2024-12-18 00:00:00'),
#   Timestamp('2024-12-25 00:00:00'),
#   Timestamp('2025-01-26 00:00:00'),
#   Timestamp('2025-01-29 00:00:00'),
#   Timestamp('2025-02-01 00:00:00'),
#   Timestamp('2025-02-12 00:00:00'),
#   Timestamp('2025-02-28 00:00:00'),
#   Timestamp('2025-03-28 00:00:00')],
#  'SEATED_CABLE_ROW': [Timestamp('2025-04-17 00:00:00'),
#   Timestamp('2025-06-13 00:00:00'),
#   Timestamp('2025-06-18 00:00:00'),
#   Timestamp('2025-06-20 00:00:00'),
#   Timestamp('2025-06-24 00:00:00'),
#   Timestamp('2025-06-26 00:00:00'),
#   Timestamp('2025-07-10 00:00:00')],
#  'SEATED_LEG_U': [Timestamp('2025-07-08 00:00:00'),
#   Timestamp('2025-07-10 00:00:00')],
#  'SHOULDER_PRESS': [Timestamp('2024-11-11 00:00:00'),
#   Timestamp('2024-11-13 00:00:00'),
#   Timestamp('2024-11-18 00:00:00'),
#   Timestamp('2024-11-20 00:00:00'),
#   Timestamp('2024-11-26 00:00:00'),
#   Timestamp('2024-11-28 00:00:00'),
#   Timestamp('2024-12-03 00:00:00'),
#   Timestamp('2024-12-05 00:00:00'),
#   Timestamp('2024-12-12 00:00:00'),
#   Timestamp('2024-12-17 00:00:00'),
#   Timestamp('2024-12-26 00:00:00'),
#   Timestamp('2024-12-30 00:00:00'),
#   Timestamp('2024-12-31 00:00:00'),
#   Timestamp('2025-01-02 00:00:00'),
#   Timestamp('2025-01-10 00:00:00'),
#   Timestamp('2025-04-21 00:00:00'),
#   Timestamp('2025-06-12 00:00:00'),
#   Timestamp('2025-06-17 00:00:00'),
#   Timestamp('2025-06-19 00:00:00')],
#  'SHOULDER_PUSH_UP': [Timestamp('2025-05-10 00:00:00'),
#   Timestamp('2025-05-24 00:00:00')],
#  'SIT_UP': [Timestamp('2024-12-31 00:00:00'),
#   Timestamp('2025-01-02 00:00:00'),
#   Timestamp('2025-01-03 00:00:00'),
#   Timestamp('2025-01-06 00:00:00'),
#   Timestamp('2025-01-07 00:00:00'),
#   Timestamp('2025-01-08 00:00:00'),
#   Timestamp('2025-01-09 00:00:00'),
#   Timestamp('2025-01-13 00:00:00'),
#   Timestamp('2025-01-15 00:00:00'),
#   Timestamp('2025-01-17 00:00:00'),
#   Timestamp('2025-01-29 00:00:00'),
#   Timestamp('2025-04-24 00:00:00')],
#  'SQUAT': [Timestamp('2025-04-24 00:00:00')],
#  'STANDING_CABLE_PULLOVER': [Timestamp('2024-11-15 00:00:00'),
#   Timestamp('2024-11-18 00:00:00'),
#   Timestamp('2024-11-20 00:00:00'),
#   Timestamp('2024-12-05 00:00:00'),
#   Timestamp('2025-04-22 00:00:00')],
#  'STATIC_BACK_EXTENSION': [Timestamp('2024-11-13 00:00:00'),
#   Timestamp('2024-11-19 00:00:00'),
#   Timestamp('2024-12-03 00:00:00'),
#   Timestamp('2024-12-05 00:00:00'),
#   Timestamp('2024-12-12 00:00:00'),
#   Timestamp('2025-01-22 00:00:00'),
#   Timestamp('2025-02-18 00:00:00'),
#   Timestamp('2025-04-20 00:00:00')],
#  'TRAP_BAR_DEADLIFT': [Timestamp('2025-01-02 00:00:00')],
#  'TRICEPS_PRESSDOWN': [Timestamp('2024-12-17 00:00:00'),
#   Timestamp('2025-05-30 00:00:00'),
#   Timestamp('2025-06-04 00:00:00'),
#   Timestamp('2025-06-09 00:00:00')],
#  'UNKNOWN': [Timestamp('2024-11-12 00:00:00'),
#   Timestamp('2024-11-13 00:00:00'),
#   Timestamp('2024-11-14 00:00:00'),
#   Timestamp('2024-11-16 00:00:00'),
#   Timestamp('2024-11-19 00:00:00'),
#   Timestamp('2024-11-22 00:00:00'),
#   Timestamp('2024-11-25 00:00:00'),
#   Timestamp('2024-11-26 00:00:00'),
#   Timestamp('2024-11-28 00:00:00'),
#   Timestamp('2024-11-29 00:00:00'),
#   Timestamp('2024-12-02 00:00:00'),
#   Timestamp('2024-12-05 00:00:00'),
#   Timestamp('2024-12-11 00:00:00'),
#   Timestamp('2024-12-13 00:00:00'),
#   Timestamp('2024-12-18 00:00:00'),
#   Timestamp('2024-12-23 00:00:00'),
#   Timestamp('2024-12-27 00:00:00'),
#   Timestamp('2024-12-30 00:00:00'),
#   Timestamp('2024-12-31 00:00:00'),
#   Timestamp('2025-01-02 00:00:00'),
#   Timestamp('2025-01-06 00:00:00'),
#   Timestamp('2025-01-08 00:00:00'),
#   Timestamp('2025-01-10 00:00:00'),
#   Timestamp('2025-01-13 00:00:00'),
#   Timestamp('2025-01-15 00:00:00'),
#   Timestamp('2025-01-17 00:00:00'),
#   Timestamp('2025-01-20 00:00:00'),
#   Timestamp('2025-01-22 00:00:00'),
#   Timestamp('2025-01-24 00:00:00'),
#   Timestamp('2025-01-26 00:00:00'),
#   Timestamp('2025-01-29 00:00:00'),
#   Timestamp('2025-01-30 00:00:00'),
#   Timestamp('2025-02-04 00:00:00'),
#   Timestamp('2025-02-12 00:00:00'),
#   Timestamp('2025-02-18 00:00:00'),
#   Timestamp('2025-02-21 00:00:00'),
#   Timestamp('2025-02-26 00:00:00'),
#   Timestamp('2025-02-28 00:00:00'),
#   Timestamp('2025-03-14 00:00:00'),
#   Timestamp('2025-03-17 00:00:00'),
#   Timestamp('2025-03-19 00:00:00'),
#   Timestamp('2025-03-21 00:00:00'),
#   Timestamp('2025-03-25 00:00:00'),
#   Timestamp('2025-03-28 00:00:00'),
#   Timestamp('2025-03-31 00:00:00'),
#   Timestamp('2025-04-07 00:00:00'),
#   Timestamp('2025-04-23 00:00:00'),
#   Timestamp('2025-04-24 00:00:00')],
#  'WEIGHTED_LEG_CURL': [Timestamp('2024-11-14 00:00:00'),
#   Timestamp('2024-11-21 00:00:00')],
#  'WEIGHTED_LEG_EXTENSIONS': [Timestamp('2024-11-11 00:00:00'),
#   Timestamp('2024-11-13 00:00:00'),
#   Timestamp('2024-11-15 00:00:00'),
#   Timestamp('2024-11-19 00:00:00'),
#   Timestamp('2024-11-21 00:00:00'),
#   Timestamp('2024-11-26 00:00:00'),
#   Timestamp('2024-12-03 00:00:00'),
#   Timestamp('2024-12-05 00:00:00'),
#   Timestamp('2024-12-12 00:00:00'),
#   Timestamp('2024-12-17 00:00:00'),
#   Timestamp('2024-12-26 00:00:00'),
#   Timestamp('2024-12-31 00:00:00')],
#  'WEIGHTED_STATIC_BACK_EXTENSION': [Timestamp('2025-01-24 00:00:00')],
#  'WIDE_GRIP_LAT_PULLDOWN': [Timestamp('2024-11-11 00:00:00'),
#   Timestamp('2024-11-13 00:00:00'),
#   Timestamp('2024-11-15 00:00:00'),
#   Timestamp('2024-11-18 00:00:00'),
#   Timestamp('2024-11-25 00:00:00'),
#   Timestamp('2024-11-27 00:00:00'),
#   Timestamp('2024-11-29 00:00:00'),
#   Timestamp('2024-12-02 00:00:00'),
#   Timestamp('2024-12-04 00:00:00'),
#   Timestamp('2024-12-06 00:00:00'),
#   Timestamp('2024-12-13 00:00:00'),
#   Timestamp('2024-12-18 00:00:00'),
#   Timestamp('2024-12-25 00:00:00'),
#   Timestamp('2024-12-27 00:00:00'),
#   Timestamp('2024-12-30 00:00:00'),
#   Timestamp('2025-01-08 00:00:00'),
#   Timestamp('2025-01-10 00:00:00'),
#   Timestamp('2025-01-13 00:00:00'),
#   Timestamp('2025-01-15 00:00:00'),
#   Timestamp('2025-01-17 00:00:00'),
#   Timestamp('2025-01-20 00:00:00'),
#   Timestamp('2025-01-22 00:00:00'),
#   Timestamp('2025-01-24 00:00:00'),
#   Timestamp('2025-01-30 00:00:00'),
#   Timestamp('2025-02-08 00:00:00'),
#   Timestamp('2025-02-10 00:00:00'),
#   Timestamp('2025-02-19 00:00:00'),
#   Timestamp('2025-02-28 00:00:00'),
#   Timestamp('2025-04-01 00:00:00'),
#   Timestamp('2025-04-03 00:00:00'),
#   Timestamp('2025-04-16 00:00:00'),
#   Timestamp('2025-04-17 00:00:00'),
#   Timestamp('2025-04-22 00:00:00'),
#   Timestamp('2025-05-26 00:00:00'),
#   Timestamp('2025-06-13 00:00:00'),
#   Timestamp('2025-06-18 00:00:00'),
#   Timestamp('2025-06-20 00:00:00'),
#   Timestamp('2025-06-24 00:00:00'),
#   Timestamp('2025-06-26 00:00:00')],
#  'WIDE_GRIP_SEATED_CABLE_ROW': [Timestamp('2025-07-08 00:00:00')],
#  '_90_DEGREE_CABLE_EXTERNAL_ROTATION': [Timestamp('2025-07-07 00:00:00'),
#   Timestamp('2025-07-09 00:00:00')]}

# %%
# 日期 → 动作字典
date_to_movements = agg_info.groupby("fmt_exercise_date").apply(
    lambda g: {
        row["fmt_movement"]: {"weight": row["weight"], "reps": row["repetition_count"]}
        for _, row in g.iterrows()
    }
).to_dict()
date_to_movements
# Out:
# /var/folders/h7/rkzrdq796dn5vxbv_r4nk0yw0000gn/T/ipykernel_77800/531935624.py:2: FutureWarning: DataFrameGroupBy.apply operated on the grouping columns. This behavior is deprecated, and in a future version of pandas the grouping columns will be excluded from the operation. Either pass `include_groups=False` to exclude the groupings or explicitly select the grouping columns after groupby to silence this warning.
#   date_to_movements = agg_info.groupby("fmt_exercise_date").apply(
# {Timestamp('2024-11-08 00:00:00'): {'BAR_HOLDS': {'weight': 35000.0,
#    'reps': 100}},
#  Timestamp('2024-11-11 00:00:00'): {'BARBELL_ROW': {'weight': 22000.0,
#    'reps': 43},
#   'LEG_ADDUCTION': {'weight': 161000.0, 'reps': 74},
#   'SHOULDER_PRESS': {'weight': 112000.0, 'reps': 54},
#   'WEIGHTED_LEG_EXTENSIONS': {'weight': 154000.0, 'reps': 32},
#   'WIDE_GRIP_LAT_PULLDOWN': {'weight': 196000.0, 'reps': 54}},
#  Timestamp('2024-11-12 00:00:00'): {'CHEST_PRESS_WITH_BAND': {'weight': 105000.0,
#    'reps': 46},
#   'FLYE': {'weight': 210000.0, 'reps': 53},
#   'UNKNOWN': {'weight': 70000.0, 'reps': 200}},
#  Timestamp('2024-11-13 00:00:00'): {'LEG_ADDUCTION': {'weight': 105000.0,
#    'reps': 36},
#   'SHOULDER_PRESS': {'weight': 77000.0, 'reps': 35},
#   'STATIC_BACK_EXTENSION': {'weight': 0.0, 'reps': 28},
#   'UNKNOWN': {'weight': 105000.0, 'reps': 38},
#   'WEIGHTED_LEG_EXTENSIONS': {'weight': 112000.0, 'reps': 20},
#   'WIDE_GRIP_LAT_PULLDOWN': {'weight': 133000.0, 'reps': 42}},
#  Timestamp('2024-11-14 00:00:00'): {'CHEST_PRESS_WITH_BAND': {'weight': 112000.0,
#    'reps': 46},
#   'CURL': {'weight': 30000.0, 'reps': 40},
#   'FLYE': {'weight': 287000.0, 'reps': 74},
#   'UNKNOWN': {'weight': 70000.0, 'reps': 200},
#   'WEIGHTED_LEG_CURL': {'weight': 105000.0, 'reps': 28}},
#  Timestamp('2024-11-15 00:00:00'): {'INCLINE_REVERSE_FLYE': {'weight': 98000.0,
#    'reps': 34},
#   'LEG_ADDUCTION': {'weight': 182000.0, 'reps': 56},
#   'STANDING_CABLE_PULLOVER': {'weight': 30000.0, 'reps': 30},
#   'WEIGHTED_LEG_EXTENSIONS': {'weight': 168000.0, 'reps': 32},
#   'WIDE_GRIP_LAT_PULLDOWN': {'weight': 105000.0, 'reps': 35}},
#  Timestamp('2024-11-16 00:00:00'): {'UNKNOWN': {'weight': 70000.0,
#    'reps': 200}},
#  Timestamp('2024-11-18 00:00:00'): {'LEG_ADDUCTION': {'weight': 119000.0,
#    'reps': 38},
#   'SHOULDER_PRESS': {'weight': 105000.0, 'reps': 40},
#   'STANDING_CABLE_PULLOVER': {'weight': 35500.0, 'reps': 36},
#   'WIDE_GRIP_LAT_PULLDOWN': {'weight': 196000.0, 'reps': 52}},
#  Timestamp('2024-11-19 00:00:00'): {'CHEST_PRESS_WITH_BAND': {'weight': 105000.0,
#    'reps': 45},
#   'CURL': {'weight': 22000.0, 'reps': 32},
#   'FLYE': {'weight': 203000.0, 'reps': 46},
#   'STATIC_BACK_EXTENSION': {'weight': 0.0, 'reps': 28},
#   'UNKNOWN': {'weight': 70000.0, 'reps': 200},
#   'WEIGHTED_LEG_EXTENSIONS': {'weight': 252000.0, 'reps': 40}},
#  Timestamp('2024-11-20 00:00:00'): {'INCLINE_REVERSE_FLYE': {'weight': 168000.0,
#    'reps': 62},
#   'LEG_ADDUCTION': {'weight': 126000.0, 'reps': 39},
#   'SHOULDER_PRESS': {'weight': 108500.0, 'reps': 46},
#   'STANDING_CABLE_PULLOVER': {'weight': 40000.0, 'reps': 46}},
#  Timestamp('2024-11-21 00:00:00'): {'CHEST_PRESS_WITH_BAND': {'weight': 98000.0,
#    'reps': 46},
#   'CURL': {'weight': 30000.0, 'reps': 38},
#   'FLYE': {'weight': 231000.0, 'reps': 56},
#   'WEIGHTED_LEG_CURL': {'weight': 105000.0, 'reps': 30},
#   'WEIGHTED_LEG_EXTENSIONS': {'weight': 252000.0, 'reps': 40}},
#  Timestamp('2024-11-22 00:00:00'): {'INCLINE_REVERSE_FLYE': {'weight': 133000.0,
#    'reps': 62},
#   'LEG_ADDUCTION': {'weight': 126000.0, 'reps': 30},
#   'ROW': {'weight': 92500.0, 'reps': 79},
#   'UNKNOWN': {'weight': 70000.0, 'reps': 200}},
#  Timestamp('2024-11-25 00:00:00'): {'INCLINE_REVERSE_FLYE': {'weight': 140000.0,
#    'reps': 50},
#   'LEG_ADDUCTION': {'weight': 126000.0, 'reps': 30},
#   'ROW': {'weight': 37500.0, 'reps': 48},
#   'UNKNOWN': {'weight': 70000.0, 'reps': 200},
#   'WIDE_GRIP_LAT_PULLDOWN': {'weight': 182000.0, 'reps': 54}},
#  Timestamp('2024-11-26 00:00:00'): {'CHEST_PRESS_WITH_BAND': {'weight': 147000.0,
#    'reps': 56},
#   'FLYE': {'weight': 413000.0, 'reps': 78},
#   'SHOULDER_PRESS': {'weight': 63000.0, 'reps': 40},
#   'UNKNOWN': {'weight': 0.0, 'reps': 24},
#   'WEIGHTED_LEG_EXTENSIONS': {'weight': 210000.0, 'reps': 26}},
#  Timestamp('2024-11-27 00:00:00'): {'CURL': {'weight': 24000.0, 'reps': 32},
#   'INCLINE_REVERSE_FLYE': {'weight': 140000.0, 'reps': 55},
#   'LEG_ADDUCTION': {'weight': 126000.0, 'reps': 42},
#   'ROW': {'weight': 60000.0, 'reps': 48},
#   'WIDE_GRIP_LAT_PULLDOWN': {'weight': 175000.0, 'reps': 62}},
#  Timestamp('2024-11-28 00:00:00'): {'CHEST_PRESS_WITH_BAND': {'weight': 168000.0,
#    'reps': 68},
#   'FLYE': {'weight': 336000.0, 'reps': 70},
#   'LEG_EXTENSION': {'weight': 217000.0, 'reps': 30},
#   'SHOULDER_PRESS': {'weight': 63000.0, 'reps': 34},
#   'UNKNOWN': {'weight': 10000.0, 'reps': 34}},
#  Timestamp('2024-11-29 00:00:00'): {'INCLINE_REVERSE_FLYE': {'weight': 133000.0,
#    'reps': 38},
#   'LEG_ADDUCTION': {'weight': 189000.0, 'reps': 44},
#   'ROW': {'weight': 45000.0, 'reps': 36},
#   'UNKNOWN': {'weight': 90000.0, 'reps': 200},
#   'WIDE_GRIP_LAT_PULLDOWN': {'weight': 154000.0, 'reps': 42}},
#  Timestamp('2024-12-02 00:00:00'): {'CABLE_ROW_STANDING': {'weight': 45000.0,
#    'reps': 40},
#   'INCLINE_REVERSE_FLYE': {'weight': 126000.0, 'reps': 36},
#   'LEG_ADDUCTION': {'weight': 147000.0, 'reps': 34},
#   'UNKNOWN': {'weight': 90000.0, 'reps': 200},
#   'WIDE_GRIP_LAT_PULLDOWN': {'weight': 126000.0, 'reps': 46}},
#  Timestamp('2024-12-03 00:00:00'): {'CHEST_PRESS_WITH_BAND': {'weight': 154000.0,
#    'reps': 57},
#   'CURL': {'weight': 38000.0, 'reps': 32},
#   'FLYE': {'weight': 272000.0, 'reps': 64},
#   'SHOULDER_PRESS': {'weight': 91000.0, 'reps': 42},
#   'STATIC_BACK_EXTENSION': {'weight': 0.0, 'reps': 30},
#   'WEIGHTED_LEG_EXTENSIONS': {'weight': 231000.0, 'reps': 28}},
#  Timestamp('2024-12-04 00:00:00'): {'CABLE_ROW_STANDING': {'weight': 60000.0,
#    'reps': 46},
#   'INCLINE_REVERSE_FLYE': {'weight': 126000.0, 'reps': 42},
#   'LEG_ADDUCTION': {'weight': 154000.0, 'reps': 34},
#   'WIDE_GRIP_LAT_PULLDOWN': {'weight': 126000.0, 'reps': 50}},
#  Timestamp('2024-12-05 00:00:00'): {'CHEST_PRESS_WITH_BAND': {'weight': 231000.0,
#    'reps': 54},
#   'FLYE': {'weight': 231000.0, 'reps': 58},
#   'SHOULDER_PRESS': {'weight': 70000.0, 'reps': 34},
#   'STANDING_CABLE_PULLOVER': {'weight': 35000.0, 'reps': 42},
#   'STATIC_BACK_EXTENSION': {'weight': 0.0, 'reps': 30},
#   'UNKNOWN': {'weight': 90000.0, 'reps': 200},
#   'WEIGHTED_LEG_EXTENSIONS': {'weight': 231000.0, 'reps': 30}},
#  Timestamp('2024-12-06 00:00:00'): {'INCLINE_REVERSE_FLYE': {'weight': 154000.0,
#    'reps': 48},
#   'LEG_ADDUCTION': {'weight': 168000.0, 'reps': 30},
#   'ROW': {'weight': 67500.0, 'reps': 42},
#   'WIDE_GRIP_LAT_PULLDOWN': {'weight': 154000.0, 'reps': 59}},
#  Timestamp('2024-12-11 00:00:00'): {'UNKNOWN': {'weight': 100000.0,
#    'reps': 200}},
#  Timestamp('2024-12-12 00:00:00'): {'CHEST_PRESS_WITH_BAND': {'weight': 231000.0,
#    'reps': 58},
#   'FLYE': {'weight': 231000.0, 'reps': 62},
#   'ROPE_PRESSDOWN': {'weight': 50000.0, 'reps': 48},
#   'SHOULDER_PRESS': {'weight': 91000.0, 'reps': 34},
#   'STATIC_BACK_EXTENSION': {'weight': 0.0, 'reps': 30},
#   'WEIGHTED_LEG_EXTENSIONS': {'weight': 231000.0, 'reps': 30}},
#  Timestamp('2024-12-13 00:00:00'): {'INCLINE_REVERSE_FLYE': {'weight': 126000.0,
#    'reps': 34},
#   'LEG_ADDUCTION': {'weight': 168000.0, 'reps': 39},
#   'ROW': {'weight': 62500.0, 'reps': 48},
#   'UNKNOWN': {'weight': 100000.0, 'reps': 200},
#   'WIDE_GRIP_LAT_PULLDOWN': {'weight': 126000.0, 'reps': 48}},
#  Timestamp('2024-12-16 00:00:00'): {'CABLE_ROW_STANDING': {'weight': 62500.0,
#    'reps': 42},
#   'CURL': {'weight': 36000.0, 'reps': 36},
#   'INCLINE_REVERSE_FLYE': {'weight': 154000.0, 'reps': 46},
#   'LEG_ADDUCTION': {'weight': 168000.0, 'reps': 30}},
#  Timestamp('2024-12-17 00:00:00'): {'CHEST_PRESS_WITH_BAND': {'weight': 126000.0,
#    'reps': 45},
#   'FLYE': {'weight': 210000.0, 'reps': 60},
#   'SHOULDER_PRESS': {'weight': 105000.0, 'reps': 36},
#   'TRICEPS_PRESSDOWN': {'weight': 60000.0, 'reps': 48},
#   'WEIGHTED_LEG_EXTENSIONS': {'weight': 252000.0, 'reps': 30}},
#  Timestamp('2024-12-18 00:00:00'): {'INCLINE_REVERSE_FLYE': {'weight': 168000.0,
#    'reps': 48},
#   'ROW': {'weight': 52500.0, 'reps': 36},
#   'UNKNOWN': {'weight': 168000.0, 'reps': 26},
#   'WIDE_GRIP_LAT_PULLDOWN': {'weight': 168000.0, 'reps': 63}},
#  Timestamp('2024-12-23 00:00:00'): {'UNKNOWN': {'weight': 110000.0,
#    'reps': 200}},
#  Timestamp('2024-12-25 00:00:00'): {'INCLINE_REVERSE_FLYE': {'weight': 105000.0,
#    'reps': 28},
#   'LEG_ADDUCTION': {'weight': 147000.0, 'reps': 34},
#   'ROW': {'weight': 50000.0, 'reps': 38},
#   'WIDE_GRIP_LAT_PULLDOWN': {'weight': 105000.0, 'reps': 30}},
#  Timestamp('2024-12-26 00:00:00'): {'CHEST_PRESS_WITH_BAND': {'weight': 126000.0,
#    'reps': 40},
#   'FLYE': {'weight': 182000.0, 'reps': 36},
#   'SHOULDER_PRESS': {'weight': 84000.0, 'reps': 24},
#   'WEIGHTED_LEG_EXTENSIONS': {'weight': 252000.0, 'reps': 26}},
#  Timestamp('2024-12-27 00:00:00'): {'CABLE_ROW_STANDING': {'weight': 60000.0,
#    'reps': 35},
#   'INCLINE_REVERSE_FLYE': {'weight': 105000.0, 'reps': 26},
#   'LEG_ADDUCTION': {'weight': 147000.0, 'reps': 32},
#   'UNKNOWN': {'weight': 110000.0, 'reps': 200},
#   'WIDE_GRIP_LAT_PULLDOWN': {'weight': 105000.0, 'reps': 35}},
#  Timestamp('2024-12-30 00:00:00'): {'CABLE_ROW_STANDING': {'weight': 65000.0,
#    'reps': 42},
#   'INCLINE_REVERSE_FLYE': {'weight': 154000.0, 'reps': 32},
#   'SHOULDER_PRESS': {'weight': 84000.0, 'reps': 34},
#   'UNKNOWN': {'weight': 147000.0, 'reps': 30},
#   'WIDE_GRIP_LAT_PULLDOWN': {'weight': 154000.0, 'reps': 42}},
#  Timestamp('2024-12-31 00:00:00'): {'CABLE_ROW_STANDING': {'weight': 60000.0,
#    'reps': 32},
#   'CHEST_PRESS_WITH_BAND': {'weight': 147000.0, 'reps': 52},
#   'CURL': {'weight': 30000.0, 'reps': 24},
#   'FLYE': {'weight': 294000.0, 'reps': 60},
#   'INCLINE_REVERSE_FLYE': {'weight': 154000.0, 'reps': 34},
#   'LEG_ADDUCTION': {'weight': 147000.0, 'reps': 32},
#   'SHOULDER_PRESS': {'weight': 84000.0, 'reps': 32},
#   'SIT_UP': {'weight': 0.0, 'reps': 33},
#   'UNKNOWN': {'weight': 110000.0, 'reps': 200},
#   'WEIGHTED_LEG_EXTENSIONS': {'weight': 252000.0, 'reps': 28}},
#  Timestamp('2025-01-02 00:00:00'): {'CHEST_PRESS_WITH_BAND': {'weight': 147000.0,
#    'reps': 40},
#   'CURL': {'weight': 38000.0, 'reps': 30},
#   'FLYE': {'weight': 203000.0, 'reps': 38},
#   'LEG_EXTENSION': {'weight': 252000.0, 'reps': 32},
#   'LEG_RAISE': {'weight': 0.0, 'reps': 32},
#   'REVERSE_CRUNCH_ON_A_BENCH': {'weight': 0.0, 'reps': 34},
#   'SHOULDER_PRESS': {'weight': 84000.0, 'reps': 26},
#   'SIT_UP': {'weight': 0.0, 'reps': 28},
#   'TRAP_BAR_DEADLIFT': {'weight': 105000.0, 'reps': 35},
#   'UNKNOWN': {'weight': 110000.0, 'reps': 200}},
#  Timestamp('2025-01-03 00:00:00'): {'CABLE_ROW_STANDING': {'weight': 95000.0,
#    'reps': 52},
#   'INCLINE_REVERSE_FLYE': {'weight': 175000.0, 'reps': 48},
#   'LATERAL_RAISE': {'weight': 20000.0, 'reps': 28},
#   'LEG_ADDUCTION': {'weight': 168000.0, 'reps': 26},
#   'REVERSE_CRUNCH_ON_A_BENCH': {'weight': 0.0, 'reps': 34},
#   'SIT_UP': {'weight': 0.0, 'reps': 30}},
#  Timestamp('2025-01-06 00:00:00'): {'INCLINE_REVERSE_FLYE': {'weight': 175000.0,
#    'reps': 44},
#   'LATERAL_RAISE': {'weight': 32000.0, 'reps': 48},
#   'LEG_ADDUCTION': {'weight': 168000.0, 'reps': 26},
#   'REVERSE_CRUNCH_ON_A_BENCH': {'weight': 0.0, 'reps': 34},
#   'SIT_UP': {'weight': 0.0, 'reps': 32},
#   'UNKNOWN': {'weight': 110000.0, 'reps': 200}},
#  Timestamp('2025-01-07 00:00:00'): {'CHEST_PRESS_WITH_BAND': {'weight': 105000.0,
#    'reps': 30},
#   'DEADLIFT': {'weight': 90000.0, 'reps': 39},
#   'FLYE': {'weight': 147000.0, 'reps': 30},
#   'LEG_EXTENSION': {'weight': 252000.0, 'reps': 30},
#   'REVERSE_CRUNCH_ON_A_BENCH': {'weight': 0.0, 'reps': 32},
#   'SIT_UP': {'weight': 0.0, 'reps': 30}},
#  Timestamp('2025-01-08 00:00:00'): {'CABLE_ROW_STANDING': {'weight': 65000.0,
#    'reps': 31},
#   'INCLINE_REVERSE_FLYE': {'weight': 126000.0, 'reps': 28},
#   'LATERAL_RAISE': {'weight': 24000.0, 'reps': 30},
#   'REVERSE_CRUNCH_ON_A_BENCH': {'weight': 0.0, 'reps': 36},
#   'SIT_UP': {'weight': 0.0, 'reps': 30},
#   'UNKNOWN': {'weight': 110000.0, 'reps': 200},
#   'WIDE_GRIP_LAT_PULLDOWN': {'weight': 126000.0, 'reps': 32}},
#  Timestamp('2025-01-09 00:00:00'): {'CHEST_PRESS_WITH_BAND': {'weight': 105000.0,
#    'reps': 32},
#   'CURL': {'weight': 28000.0, 'reps': 26},
#   'FLYE': {'weight': 147000.0, 'reps': 28},
#   'LEG_EXTENSION': {'weight': 252000.0, 'reps': 30},
#   'REVERSE_CRUNCH_ON_A_BENCH': {'weight': 0.0, 'reps': 32},
#   'SIT_UP': {'weight': 0.0, 'reps': 32}},
#  Timestamp('2025-01-10 00:00:00'): {'CABLE_ROW_STANDING': {'weight': 152500.0,
#    'reps': 58},
#   'CURL': {'weight': 30000.0, 'reps': 34},
#   'DEADLIFT': {'weight': 110000.0, 'reps': 44},
#   'INCLINE_REVERSE_FLYE': {'weight': 126000.0, 'reps': 26},
#   'LATERAL_RAISE': {'weight': 30000.0, 'reps': 42},
#   'LEG_ADDUCTION': {'weight': 168000.0, 'reps': 32},
#   'SHOULDER_PRESS': {'weight': 98000.0, 'reps': 30},
#   'UNKNOWN': {'weight': 110000.0, 'reps': 200},
#   'WIDE_GRIP_LAT_PULLDOWN': {'weight': 126000.0, 'reps': 28}},
#  Timestamp('2025-01-13 00:00:00'): {'CABLE_ROW_STANDING': {'weight': 120000.0,
#    'reps': 50},
#   'CHEST_PRESS_WITH_BAND': {'weight': 126000.0, 'reps': 40},
#   'CURL': {'weight': 30000.0, 'reps': 24},
#   'DEADLIFT': {'weight': 130000.0, 'reps': 40},
#   'FLYE': {'weight': 182000.0, 'reps': 36},
#   'INCLINE_REVERSE_FLYE': {'weight': 147000.0, 'reps': 27},
#   'LATERAL_RAISE': {'weight': 34000.0, 'reps': 46},
#   'LEG_ADDUCTION': {'weight': 168000.0, 'reps': 28},
#   'LEG_EXTENSION': {'weight': 252000.0, 'reps': 28},
#   'REVERSE_CRUNCH_ON_A_BENCH': {'weight': 0.0, 'reps': 34},
#   'SIT_UP': {'weight': 0.0, 'reps': 30},
#   'UNKNOWN': {'weight': 110000.0, 'reps': 200},
#   'WIDE_GRIP_LAT_PULLDOWN': {'weight': 210000.0, 'reps': 48}},
#  Timestamp('2025-01-15 00:00:00'): {'CABLE_ROW_STANDING': {'weight': 80000.0,
#    'reps': 32},
#   'CHEST_PRESS_WITH_BAND': {'weight': 126000.0, 'reps': 40},
#   'DEADLIFT': {'weight': 130000.0, 'reps': 40},
#   'FLYE': {'weight': 182000.0, 'reps': 40},
#   'INCLINE_REVERSE_FLYE': {'weight': 126000.0, 'reps': 26},
#   'LATERAL_RAISE': {'weight': 28000.0, 'reps': 38},
#   'LEG_ADDUCTION': {'weight': 168000.0, 'reps': 24},
#   'REVERSE_CRUNCH_ON_A_BENCH': {'weight': 0.0, 'reps': 36},
#   'SIT_UP': {'weight': 0.0, 'reps': 29},
#   'UNKNOWN': {'weight': 110000.0, 'reps': 200},
#   'WIDE_GRIP_LAT_PULLDOWN': {'weight': 126000.0, 'reps': 26}},
#  Timestamp('2025-01-17 00:00:00'): {'CABLE_ROW_STANDING': {'weight': 92500.0,
#    'reps': 40},
#   'CHEST_PRESS_WITH_BAND': {'weight': 105000.0, 'reps': 32},
#   'DEADLIFT': {'weight': 150000.0, 'reps': 58},
#   'FLYE': {'weight': 147000.0, 'reps': 30},
#   'INCLINE_REVERSE_FLYE': {'weight': 154000.0, 'reps': 38},
#   'LATERAL_RAISE': {'weight': 28000.0, 'reps': 42},
#   'LEG_ADDUCTION': {'weight': 168000.0, 'reps': 28},
#   'LEG_EXTENSION': {'weight': 252000.0, 'reps': 30},
#   'REVERSE_CRUNCH_ON_A_BENCH': {'weight': 0.0, 'reps': 34},
#   'SIT_UP': {'weight': 0.0, 'reps': 28},
#   'UNKNOWN': {'weight': 110000.0, 'reps': 200},
#   'WIDE_GRIP_LAT_PULLDOWN': {'weight': 154000.0, 'reps': 42}},
#  Timestamp('2025-01-20 00:00:00'): {'CABLE_ROW_STANDING': {'weight': 97500.0,
#    'reps': 42},
#   'CHEST_PRESS_WITH_BAND': {'weight': 105000.0, 'reps': 30},
#   'DEADLIFT': {'weight': 175000.0, 'reps': 52},
#   'FLYE': {'weight': 147000.0, 'reps': 26},
#   'INCLINE_REVERSE_FLYE': {'weight': 126000.0, 'reps': 26},
#   'LATERAL_RAISE': {'weight': 28000.0, 'reps': 44},
#   'LEG_ADDUCTION': {'weight': 168000.0, 'reps': 28},
#   'LEG_EXTENSION': {'weight': 273000.0, 'reps': 26},
#   'UNKNOWN': {'weight': 110000.0, 'reps': 200},
#   'WIDE_GRIP_LAT_PULLDOWN': {'weight': 126000.0, 'reps': 30}},
#  Timestamp('2025-01-22 00:00:00'): {'CABLE_ROW_STANDING': {'weight': 130000.0,
#    'reps': 46},
#   'CHEST_PRESS_WITH_BAND': {'weight': 105000.0, 'reps': 32},
#   'FLYE': {'weight': 147000.0, 'reps': 30},
#   'INCLINE_REVERSE_FLYE': {'weight': 126000.0, 'reps': 26},
#   'LATERAL_RAISE': {'weight': 32000.0, 'reps': 52},
#   'LEG_PRESS': {'weight': 195000.0, 'reps': 26},
#   'STATIC_BACK_EXTENSION': {'weight': 0.0, 'reps': 26},
#   'UNKNOWN': {'weight': 110000.0, 'reps': 200},
#   'WIDE_GRIP_LAT_PULLDOWN': {'weight': 126000.0, 'reps': 32}},
#  Timestamp('2025-01-24 00:00:00'): {'CABLE_ROW_STANDING': {'weight': 100000.0,
#    'reps': 45},
#   'CHEST_PRESS_WITH_BAND': {'weight': 105000.0, 'reps': 32},
#   'FLYE': {'weight': 147000.0, 'reps': 30},
#   'INCLINE_REVERSE_FLYE': {'weight': 126000.0, 'reps': 28},
#   'LATERAL_RAISE': {'weight': 32000.0, 'reps': 50},
#   'LEG_PRESS': {'weight': 209000.0, 'reps': 32},
#   'UNKNOWN': {'weight': 110000.0, 'reps': 200},
#   'WEIGHTED_STATIC_BACK_EXTENSION': {'weight': 18000.0, 'reps': 24},
#   'WIDE_GRIP_LAT_PULLDOWN': {'weight': 126000.0, 'reps': 32}},
#  Timestamp('2025-01-26 00:00:00'): {'BARBELL_DEADLIFT': {'weight': 81000.0,
#    'reps': 51},
#   'LEG_ABDUCTION': {'weight': 90000.0, 'reps': 40},
#   'ROW': {'weight': 30000.0, 'reps': 56},
#   'UNKNOWN': {'weight': 390000.0, 'reps': 238}},
#  Timestamp('2025-01-29 00:00:00'): {'BARBELL_DEADLIFT': {'weight': 15000.0,
#    'reps': 31},
#   'CURL': {'weight': 20000.0, 'reps': 32},
#   'DEADLIFT': {'weight': 45000.0, 'reps': 47},
#   'LATERAL_RAISE': {'weight': 10000.0, 'reps': 15},
#   'LEG_ABDUCTION': {'weight': 45000.0, 'reps': 60},
#   'ROW': {'weight': 22000.0, 'reps': 35},
#   'SIT_UP': {'weight': 10000.0, 'reps': 38},
#   'UNKNOWN': {'weight': 79000.0, 'reps': 104}},
#  Timestamp('2025-01-30 00:00:00'): {'BARBELL_DEADLIFT': {'weight': 27000.0,
#    'reps': 20},
#   'BARBELL_ROW': {'weight': 44000.0, 'reps': 68},
#   'CHEST_PRESS_WITH_BAND': {'weight': 280000.0, 'reps': 86},
#   'LATERAL_RAISE': {'weight': 27000.0, 'reps': 50},
#   'UNKNOWN': {'weight': 13500.0, 'reps': 15},
#   'WIDE_GRIP_LAT_PULLDOWN': {'weight': 90000.0, 'reps': 36}},
#  Timestamp('2025-02-01 00:00:00'): {'DEADLIFT': {'weight': 45000.0,
#    'reps': 50},
#   'LEG_ABDUCTION': {'weight': 45000.0, 'reps': 49},
#   'ROW': {'weight': 30000.0, 'reps': 42}},
#  Timestamp('2025-02-04 00:00:00'): {'BARBELL_DEADLIFT': {'weight': 20000.0,
#    'reps': 20},
#   'UNKNOWN': {'weight': 10000.0, 'reps': 10}},
#  Timestamp('2025-02-08 00:00:00'): {'BARBELL_DEADLIFT': {'weight': 94000.0,
#    'reps': 43},
#   'BARBELL_SHOULDER_PRESS': {'weight': 15000.0, 'reps': 37},
#   'CABLE_ROW_STANDING': {'weight': 105000.0, 'reps': 43},
#   'LATERAL_RAISE': {'weight': 33000.0, 'reps': 42},
#   'WIDE_GRIP_LAT_PULLDOWN': {'weight': 90000.0, 'reps': 47}},
#  Timestamp('2025-02-09 00:00:00'): {'DUMBBELL_FLYE': {'weight': 41000.0,
#    'reps': 46},
#   'ONE_ARM_BENT_OVER_ROW': {'weight': 29500.0, 'reps': 31}},
#  Timestamp('2025-02-10 00:00:00'): {'BENT_OVER_ROW_WITH_DUMBELL': {'weight': 60000.0,
#    'reps': 46},
#   'CHEST_PRESS_WITH_BAND': {'weight': 210000.0, 'reps': 66},
#   'DUMBBELL_DEADLIFT': {'weight': 60000.0, 'reps': 30},
#   'DUMBBELL_SHOULDER_PRESS': {'weight': 15000.0, 'reps': 35},
#   'LATERAL_RAISE': {'weight': 27500.0, 'reps': 45},
#   'WIDE_GRIP_LAT_PULLDOWN': {'weight': 100000.0, 'reps': 37}},
#  Timestamp('2025-02-11 00:00:00'): {'CALF_RAISE': {'weight': 75000.0,
#    'reps': 95},
#   'CHEST_PRESS_WITH_BAND': {'weight': 135000.0, 'reps': 30},
#   'DUMBBELL_FLYE': {'weight': 50000.0, 'reps': 52}},
#  Timestamp('2025-02-12 00:00:00'): {'BARBELL_DEADLIFT': {'weight': 45000.0,
#    'reps': 10},
#   'BENCH_PRESS': {'weight': 50000.0, 'reps': 12},
#   'INCLINE_DUMBBELL_FLYE': {'weight': 45000.0, 'reps': 47},
#   'LATERAL_RAISE': {'weight': 35000.0, 'reps': 38},
#   'PULL_UP': {'weight': 50000.0, 'reps': 8},
#   'ROW': {'weight': 110000.0, 'reps': 46},
#   'UNKNOWN': {'weight': 145000.0, 'reps': 74}},
#  Timestamp('2025-02-18 00:00:00'): {'BAR_HOLDS': {'weight': 40000.0,
#    'reps': 100},
#   'CHEST_PRESS_WITH_BAND': {'weight': 105000.0, 'reps': 32},
#   'DUMBBELL_BENCH_PRESS': {'weight': 56000.0, 'reps': 40},
#   'FLYE': {'weight': 147000.0, 'reps': 28},
#   'LATERAL_RAISE': {'weight': 30000.0, 'reps': 28},
#   'LEG_ADDUCTION': {'weight': 112000.0, 'reps': 18},
#   'LEG_PRESS': {'weight': 188000.0, 'reps': 28},
#   'STATIC_BACK_EXTENSION': {'weight': 0.0, 'reps': 30},
#   'UNKNOWN': {'weight': 40000.0, 'reps': 100}},
#  Timestamp('2025-02-19 00:00:00'): {'BENT_OVER_ROW_WITH_DUMBELL': {'weight': 42000.0,
#    'reps': 36},
#   'INCLINE_REVERSE_FLYE': {'weight': 112000.0, 'reps': 28},
#   'LATERAL_RAISE': {'weight': 12000.0, 'reps': 20},
#   'LEG_ABDUCTION': {'weight': 189000.0, 'reps': 32},
#   'WIDE_GRIP_LAT_PULLDOWN': {'weight': 147000.0, 'reps': 28}},
#  Timestamp('2025-02-21 00:00:00'): {'BENCH_PRESS': {'weight': 58000.0,
#    'reps': 46},
#   'BENT_OVER_ROW_WITH_DUMBELL': {'weight': 42000.0, 'reps': 32},
#   'INCLINE_REVERSE_FLYE': {'weight': 175000.0, 'reps': 36},
#   'LATERAL_RAISE': {'weight': 24000.0, 'reps': 32},
#   'UNKNOWN': {'weight': 80000.0, 'reps': 200}},
#  Timestamp('2025-02-26 00:00:00'): {'BENCH_PRESS': {'weight': 58000.0,
#    'reps': 40},
#   'FLYE': {'weight': 210000.0, 'reps': 59},
#   'LATERAL_RAISE': {'weight': 30000.0, 'reps': 30},
#   'LEG_PRESS': {'weight': 181000.0, 'reps': 30},
#   'UNKNOWN': {'weight': 80000.0, 'reps': 200}},
#  Timestamp('2025-02-28 00:00:00'): {'BENCH_PRESS': {'weight': 48000.0,
#    'reps': 28},
#   'BENT_OVER_ROW_WITH_DUMBELL': {'weight': 48000.0, 'reps': 34},
#   'LEG_PRESS': {'weight': 195000.0, 'reps': 26},
#   'ROW': {'weight': 40000.0, 'reps': 100},
#   'UNKNOWN': {'weight': 40000.0, 'reps': 100},
#   'WIDE_GRIP_LAT_PULLDOWN': {'weight': 147000.0, 'reps': 36}},
#  Timestamp('2025-03-05 00:00:00'): {'CABLE_ROW_STANDING': {'weight': 125000.0,
#    'reps': 40},
#   'CHEST_PRESS_WITH_BAND': {'weight': 147000.0, 'reps': 30},
#   'INCLINE_REVERSE_FLYE': {'weight': 154000.0, 'reps': 44},
#   'LEG_PRESS': {'weight': 195000.0, 'reps': 30}},
#  Timestamp('2025-03-07 00:00:00'): {'CABLE_ROW_STANDING': {'weight': 105000.0,
#    'reps': 32},
#   'CHEST_PRESS_WITH_BAND': {'weight': 259000.0, 'reps': 46},
#   'INCLINE_REVERSE_FLYE': {'weight': 210000.0, 'reps': 48},
#   'LEG_PRESS': {'weight': 195000.0, 'reps': 30}},
#  Timestamp('2025-03-11 00:00:00'): {'BENCH_PRESS': {'weight': 50000.0,
#    'reps': 28},
#   'BENT_OVER_ROW_WITH_DUMBELL': {'weight': 50000.0, 'reps': 30},
#   'CHEST_PRESS_WITH_BAND': {'weight': 147000.0, 'reps': 28},
#   'INCLINE_REVERSE_FLYE': {'weight': 231000.0, 'reps': 43}},
#  Timestamp('2025-03-14 00:00:00'): {'BENCH_PRESS': {'weight': 54000.0,
#    'reps': 24},
#   'LATERAL_RAISE': {'weight': 26000.0, 'reps': 30},
#   'UNKNOWN': {'weight': 428000.0, 'reps': 284}},
#  Timestamp('2025-03-17 00:00:00'): {'BENCH_PRESS': {'weight': 54000.0,
#    'reps': 30},
#   'BENT_OVER_ROW_WITH_DUMBELL': {'weight': 54000.0, 'reps': 30},
#   'INCLINE_REVERSE_FLYE': {'weight': 266000.0, 'reps': 48},
#   'LATERAL_RAISE': {'weight': 28000.0, 'reps': 30},
#   'UNKNOWN': {'weight': 80000.0, 'reps': 200}},
#  Timestamp('2025-03-19 00:00:00'): {'BENCH_PRESS': {'weight': 54000.0,
#    'reps': 30},
#   'BENT_OVER_ROW_WITH_DUMBELL': {'weight': 60000.0, 'reps': 31},
#   'UNKNOWN': {'weight': 80000.0, 'reps': 200}},
#  Timestamp('2025-03-21 00:00:00'): {'UNKNOWN': {'weight': 80000.0,
#    'reps': 200}},
#  Timestamp('2025-03-25 00:00:00'): {'BENCH_PRESS': {'weight': 58000.0,
#    'reps': 24},
#   'BENT_OVER_ROW_WITH_DUMBELL': {'weight': 54000.0, 'reps': 30},
#   'CHEST_PRESS_WITH_BAND': {'weight': 168000.0, 'reps': 24},
#   'INCLINE_REVERSE_FLYE': {'weight': 238000.0, 'reps': 40},
#   'UNKNOWN': {'weight': 80000.0, 'reps': 200}},
#  Timestamp('2025-03-28 00:00:00'): {'BENCH_PRESS': {'weight': 54000.0,
#    'reps': 30},
#   'LATERAL_RAISE': {'weight': 30000.0, 'reps': 30},
#   'ROW': {'weight': 20000.0, 'reps': 8},
#   'UNKNOWN': {'weight': 470000.0, 'reps': 268}},
#  Timestamp('2025-03-31 00:00:00'): {'BENCH_PRESS': {'weight': 54000.0,
#    'reps': 30},
#   'UNKNOWN': {'weight': 80000.0, 'reps': 200}},
#  Timestamp('2025-04-01 00:00:00'): {'BENT_OVER_ROW_WITH_DUMBELL': {'weight': 58000.0,
#    'reps': 30},
#   'LATERAL_RAISE': {'weight': 26000.0, 'reps': 30},
#   'WIDE_GRIP_LAT_PULLDOWN': {'weight': 168000.0, 'reps': 28}},
#  Timestamp('2025-04-03 00:00:00'): {'BENCH_PRESS': {'weight': 54000.0,
#    'reps': 30},
#   'BENT_OVER_ROW_WITH_DUMBELL': {'weight': 60000.0, 'reps': 30},
#   'LATERAL_RAISE': {'weight': 30000.0, 'reps': 30},
#   'WIDE_GRIP_LAT_PULLDOWN': {'weight': 161000.0, 'reps': 32}},
#  Timestamp('2025-04-07 00:00:00'): {'BENT_OVER_ROW_WITH_DUMBELL': {'weight': 60000.0,
#    'reps': 30},
#   'FARMERS_WALK': {'weight': 135000.0, 'reps': 3},
#   'INCLINE_REVERSE_FLYE': {'weight': 217000.0, 'reps': 29},
#   'UNKNOWN': {'weight': 80000.0, 'reps': 200}},
#  Timestamp('2025-04-08 00:00:00'): {'BENCH_PRESS': {'weight': 60000.0,
#    'reps': 30},
#   'CHEST_PRESS_WITH_BAND': {'weight': 203000.0, 'reps': 30},
#   'LATERAL_RAISE': {'weight': 30000.0, 'reps': 30}},
#  Timestamp('2025-04-09 00:00:00'): {'BENT_OVER_ROW_WITH_DUMBELL': {'weight': 60000.0,
#    'reps': 30},
#   'FARMERS_WALK': {'weight': 175000.0, 'reps': 4},
#   'INCLINE_REVERSE_FLYE': {'weight': 203000.0, 'reps': 34}},
#  Timestamp('2025-04-11 00:00:00'): {'BARBELL_BENCH_PRESS': {'weight': 60000.0,
#    'reps': 30},
#   'CHEST_PRESS_WITH_BAND': {'weight': 182000.0, 'reps': 32},
#   'FARMERS_WALK': {'weight': 220000.0, 'reps': 5}},
#  Timestamp('2025-04-16 00:00:00'): {'BARBELL_BENCH_PRESS': {'weight': 96000.0,
#    'reps': 53},
#   'WIDE_GRIP_LAT_PULLDOWN': {'weight': 329000.0, 'reps': 64}},
#  Timestamp('2025-04-17 00:00:00'): {'FARMERS_WALK': {'weight': 270000.0,
#    'reps': 6},
#   'LATERAL_RAISE': {'weight': 20000.0, 'reps': 32},
#   'SEATED_CABLE_ROW': {'weight': 84000.0, 'reps': 22},
#   'WIDE_GRIP_LAT_PULLDOWN': {'weight': 84000.0, 'reps': 24}},
#  Timestamp('2025-04-18 00:00:00'): {'BARBELL_DEADLIFT': {'weight': 90000.0,
#    'reps': 19},
#   'INCLINE_DUMBBELL_BICEPS_CURL': {'weight': 28000.0, 'reps': 24}},
#  Timestamp('2025-04-20 00:00:00'): {'DUMBBELL_REVERSE_WRIST_CURL': {'weight': 22000.0,
#    'reps': 30},
#   'DUMBBELL_WRIST_CURL': {'weight': 32000.0, 'reps': 34},
#   'FARMERS_WALK': {'weight': 180000.0, 'reps': 4},
#   'STATIC_BACK_EXTENSION': {'weight': 0.0, 'reps': 34}},
#  Timestamp('2025-04-21 00:00:00'): {'SHOULDER_PRESS': {'weight': 238000.0,
#    'reps': 103}},
#  Timestamp('2025-04-22 00:00:00'): {'BENT_OVER_ROW_WITH_DUMBELL': {'weight': 76000.0,
#    'reps': 48},
#   'CALF_RAISE': {'weight': 40500.0, 'reps': 60},
#   'FARMERS_WALK': {'weight': 350000.0, 'reps': 7},
#   'STANDING_CABLE_PULLOVER': {'weight': 87500.0, 'reps': 64},
#   'WIDE_GRIP_LAT_PULLDOWN': {'weight': 385000.0, 'reps': 90}},
#  Timestamp('2025-04-23 00:00:00'): {'BENCH_PRESS': {'weight': 62000.0,
#    'reps': 38},
#   'UNKNOWN': {'weight': 291000.0, 'reps': 74}},
#  Timestamp('2025-04-24 00:00:00'): {'CURL': {'weight': 0.0, 'reps': 10},
#   'SIT_UP': {'weight': 0.0, 'reps': 28},
#   'SQUAT': {'weight': 50000.0, 'reps': 1},
#   'UNKNOWN': {'weight': 100000.0, 'reps': 10}},
#  Timestamp('2025-04-28 00:00:00'): {'DUMBBELL_BULGARIAN_SPLIT_SQUAT': {'weight': 0.0,
#    'reps': 28}},
#  Timestamp('2025-04-29 00:00:00'): {'BENCH_DIP': {'weight': 0.0, 'reps': 16},
#   'PUSH_UP': {'weight': 0.0, 'reps': 28}},
#  Timestamp('2025-04-30 00:00:00'): {'DIAMOND_PUSH_UP': {'weight': 0.0,
#    'reps': 28}},
#  Timestamp('2025-05-03 00:00:00'): {'BENCH_DIP': {'weight': 0.0, 'reps': 32}},
#  Timestamp('2025-05-07 00:00:00'): {'DIAMOND_PUSH_UP': {'weight': 0.0,
#    'reps': 32}},
#  Timestamp('2025-05-09 00:00:00'): {'DIAMOND_PUSH_UP': {'weight': 0.0,
#    'reps': 30}},
#  Timestamp('2025-05-10 00:00:00'): {'DUMBBELL_BULGARIAN_SPLIT_SQUAT': {'weight': 0.0,
#    'reps': 24},
#   'SHOULDER_PUSH_UP': {'weight': 0.0, 'reps': 30}},
#  Timestamp('2025-05-20 00:00:00'): {'DIAMOND_PUSH_UP': {'weight': 0.0,
#    'reps': 20}},
#  Timestamp('2025-05-24 00:00:00'): {'DIAMOND_PUSH_UP': {'weight': 0.0,
#    'reps': 26},
#   'SHOULDER_PUSH_UP': {'weight': 0.0, 'reps': 30}},
#  Timestamp('2025-05-25 00:00:00'): {'FARMERS_WALK': {'weight': 190000.0,
#    'reps': 4},
#   'INCLINE_DUMBBELL_BENCH_PRESS': {'weight': 110000.0, 'reps': 58},
#   'LEG_PRESS': {'weight': 145500.0, 'reps': 30}},
#  Timestamp('2025-05-26 00:00:00'): {'BENT_OVER_ROW_WITH_DUMBELL': {'weight': 112000.0,
#    'reps': 60},
#   'CURL': {'weight': 50000.0, 'reps': 41},
#   'WIDE_GRIP_LAT_PULLDOWN': {'weight': 203000.0, 'reps': 44}},
#  Timestamp('2025-05-27 00:00:00'): {'CALF_RAISE': {'weight': 208500.0,
#    'reps': 95},
#   'DUMBBELL_SHOULDER_PRESS': {'weight': 86000.0, 'reps': 66},
#   'FARMERS_WALK': {'weight': 190000.0, 'reps': 4}},
#  Timestamp('2025-05-28 00:00:00'): {'BENT_OVER_ROW_WITH_DUMBELL': {'weight': 146000.0,
#    'reps': 80},
#   'DUMBBELL_LATERAL_RAISE': {'weight': 38000.0, 'reps': 34},
#   'DUMBBELL_SHRUG': {'weight': 115000.0, 'reps': 44}},
#  Timestamp('2025-05-29 00:00:00'): {'CALF_RAISE': {'weight': 145500.0,
#    'reps': 60},
#   'DUMBBELL_BENCH_PRESS': {'weight': 106000.0, 'reps': 58},
#   'LEG_PRESS': {'weight': 117500.0, 'reps': 56}},
#  Timestamp('2025-05-30 00:00:00'): {'DUMBBELL_REVERSE_WRIST_CURL': {'weight': 22000.0,
#    'reps': 28},
#   'DUMBBELL_WRIST_CURL': {'weight': 26000.0, 'reps': 50},
#   'FARMERS_WALK': {'weight': 316000.0, 'reps': 7},
#   'TRICEPS_PRESSDOWN': {'weight': 70000.0, 'reps': 56}},
#  Timestamp('2025-06-04 00:00:00'): {'DUMBBELL_LATERAL_RAISE': {'weight': 30000.0,
#    'reps': 42},
#   'DUMBBELL_SHOULDER_PRESS': {'weight': 100000.0, 'reps': 70},
#   'DUMBBELL_SHRUG': {'weight': 76000.0, 'reps': 56},
#   'LEG_PRESS': {'weight': 227000.0, 'reps': 46},
#   'TRICEPS_PRESSDOWN': {'weight': 112500.0, 'reps': 78}},
#  Timestamp('2025-06-06 00:00:00'): {'BENCH_PRESS': {'weight': 122500.0,
#    'reps': 61},
#   'CABLE_BICEPS_CURL': {'weight': 55000.0, 'reps': 33},
#   'CALF_RAISE': {'weight': 136000.0, 'reps': 95},
#   'DUMBBELL_BICEPS_CURL': {'weight': 44000.0, 'reps': 32},
#   'DUMBBELL_SHRUG': {'weight': 54500.0, 'reps': 24},
#   'FARMERS_WALK': {'weight': 122500.0, 'reps': 5}},
#  Timestamp('2025-06-09 00:00:00'): {'CURL': {'weight': 50000.0, 'reps': 50},
#   'LEG_ABDUCTION': {'weight': 161000.0, 'reps': 32},
#   'ROPE_PRESSDOWN': {'weight': 82500.0, 'reps': 74},
#   'TRICEPS_PRESSDOWN': {'weight': 80000.0, 'reps': 54}},
#  Timestamp('2025-06-10 00:00:00'): {'BENT_OVER_ROW_WITH_DUMBELL': {'weight': 122000.0,
#    'reps': 58},
#   'FARMERS_WALK': {'weight': 127500.0, 'reps': 5},
#   'LEG_PRESS': {'weight': 150000.0, 'reps': 28}},
#  Timestamp('2025-06-11 00:00:00'): {'BENCH_PRESS': {'weight': 100000.0,
#    'reps': 63},
#   'CALF_RAISE': {'weight': 136000.0, 'reps': 90}},
#  Timestamp('2025-06-12 00:00:00'): {'DUMBBELL_SHRUG': {'weight': 62000.0,
#    'reps': 44},
#   'FARMERS_WALK': {'weight': 122000.0, 'reps': 5},
#   'LATERAL_RAISE': {'weight': 38000.0, 'reps': 32},
#   'SHOULDER_PRESS': {'weight': 106000.0, 'reps': 66}},
#  Timestamp('2025-06-13 00:00:00'): {'LEG_PRESS': {'weight': 150000.0,
#    'reps': 28},
#   'ROPE_PRESSDOWN': {'weight': 72500.0, 'reps': 62},
#   'SEATED_CABLE_ROW': {'weight': 273000.0, 'reps': 59},
#   'WIDE_GRIP_LAT_PULLDOWN': {'weight': 420000.0, 'reps': 96}},
#  Timestamp('2025-06-16 00:00:00'): {'CALF_RAISE': {'weight': 145500.0,
#    'reps': 90},
#   'CHEST_PRESS_WITH_BAND': {'weight': 154000.0, 'reps': 40},
#   'DUMBBELL_BENCH_PRESS': {'weight': 128000.0, 'reps': 66}},
#  Timestamp('2025-06-17 00:00:00'): {'CABLE_OVERHEAD_TRICEPS_EXTENSION': {'weight': 90000.0,
#    'reps': 70},
#   'DUMBBELL_LATERAL_RAISE': {'weight': 44000.0, 'reps': 46},
#   'FARMERS_WALK': {'weight': 100000.0, 'reps': 4},
#   'SHOULDER_PRESS': {'weight': 52000.0, 'reps': 40}},
#  Timestamp('2025-06-18 00:00:00'): {'DUMBBELL_BENCH_PRESS': {'weight': 48000.0,
#    'reps': 24},
#   'LEG_PRESS': {'weight': 159000.0, 'reps': 26},
#   'SEATED_CABLE_ROW': {'weight': 231000.0, 'reps': 58},
#   'WIDE_GRIP_LAT_PULLDOWN': {'weight': 308000.0, 'reps': 65}},
#  Timestamp('2025-06-19 00:00:00'): {'CABLE_OVERHEAD_TRICEPS_EXTENSION': {'weight': 102500.0,
#    'reps': 77},
#   'SHOULDER_PRESS': {'weight': 82000.0, 'reps': 62}},
#  Timestamp('2025-06-20 00:00:00'): {'CALF_RAISE': {'weight': 150000.0,
#    'reps': 90},
#   'DUMBBELL_BICEPS_CURL': {'weight': 36000.0, 'reps': 28},
#   'FARMERS_WALK': {'weight': 160000.0, 'reps': 6},
#   'SEATED_CABLE_ROW': {'weight': 280000.0, 'reps': 74},
#   'WIDE_GRIP_LAT_PULLDOWN': {'weight': 280000.0, 'reps': 67}},
#  Timestamp('2025-06-23 00:00:00'): {'CABLE_OVERHEAD_TRICEPS_EXTENSION': {'weight': 95000.0,
#    'reps': 80},
#   'CHEST_PRESS_WITH_BAND': {'weight': 161000.0, 'reps': 57},
#   'DUMBBELL_BENCH_PRESS': {'weight': 90000.0, 'reps': 48}},
#  Timestamp('2025-06-24 00:00:00'): {'FARMERS_WALK': {'weight': 130000.0,
#    'reps': 5},
#   'LEG_PRESS': {'weight': 163500.0, 'reps': 26},
#   'SEATED_CABLE_ROW': {'weight': 210000.0, 'reps': 48},
#   'WIDE_GRIP_LAT_PULLDOWN': {'weight': 210000.0, 'reps': 50}},
#  Timestamp('2025-06-25 00:00:00'): {'DUMBBELL_BENCH_PRESS': {'weight': 102000.0,
#    'reps': 48},
#   'LATERAL_RAISE': {'weight': 48000.0, 'reps': 46},
#   'ONE_ARM_CABLE_LATERAL_RAISE': {'weight': 10000.0, 'reps': 28}},
#  Timestamp('2025-06-26 00:00:00'): {'FARMERS_WALK': {'weight': 130000.0,
#    'reps': 5},
#   'SEATED_CABLE_ROW': {'weight': 196000.0, 'reps': 44},
#   'WIDE_GRIP_LAT_PULLDOWN': {'weight': 196000.0, 'reps': 44}},
#  Timestamp('2025-06-27 00:00:00'): {'CABLE_OVERHEAD_TRICEPS_EXTENSION': {'weight': 60000.0,
#    'reps': 52},
#   'DUMBBELL_BENCH_PRESS': {'weight': 88000.0, 'reps': 40},
#   'LEG_PRESS': {'weight': 163500.0, 'reps': 30},
#   'ONE_ARM_CABLE_LATERAL_RAISE': {'weight': 10000.0, 'reps': 30}},
#  Timestamp('2025-06-30 00:00:00'): {'CABLE_OVERHEAD_TRICEPS_EXTENSION': {'weight': 52500.0,
#    'reps': 38},
#   'DUMBBELL_BENCH_PRESS': {'weight': 96000.0, 'reps': 50},
#   'DUMBBELL_BICEPS_CURL': {'weight': 30000.0, 'reps': 24},
#   'FARMERS_WALK': {'weight': 137500.0, 'reps': 5}},
#  Timestamp('2025-07-01 00:00:00'): {'CALF_RAISE': {'weight': 163500.0,
#    'reps': 90},
#   'LEG_PRESS': {'weight': 159000.0, 'reps': 28},
#   'ONE_ARM_CABLE_LATERAL_RAISE': {'weight': 10000.0, 'reps': 28}},
#  Timestamp('2025-07-02 00:00:00'): {'CABLE_BICEPS_CURL': {'weight': 77500.0,
#    'reps': 42},
#   'CABLE_OVERHEAD_TRICEPS_EXTENSION': {'weight': 97500.0, 'reps': 81},
#   'CHEST_PRESS_WITH_BAND': {'weight': 126000.0, 'reps': 28},
#   'FARMERS_WALK': {'weight': 115000.0, 'reps': 4},
#   'FLYE': {'weight': 126000.0, 'reps': 26}},
#  Timestamp('2025-07-04 00:00:00'): {'CABLE_OVERHEAD_TRICEPS_EXTENSION': {'weight': 100000.0,
#    'reps': 63},
#   'CABLE_ROW_STANDING': {'weight': 85000.0, 'reps': 40},
#   'CHEST_PRESS_WITH_BAND': {'weight': 126000.0, 'reps': 32},
#   'DUMBBELL_BICEPS_CURL': {'weight': 44000.0, 'reps': 30},
#   'FARMERS_WALK': {'weight': 115000.0, 'reps': 4},
#   'LEG_PRESS': {'weight': 163500.0, 'reps': 30},
#   'ONE_ARM_CABLE_LATERAL_RAISE': {'weight': 17500.0, 'reps': 52}},
#  Timestamp('2025-07-07 00:00:00'): {'CABLE_OVERHEAD_TRICEPS_EXTENSION': {'weight': 125000.0,
#    'reps': 26},
#   'CALF_RAISE': {'weight': 245000.0, 'reps': 44},
#   'CHEST_PRESS_WITH_BAND': {'weight': 154000.0, 'reps': 16},
#   'DUMBBELL_BENCH_PRESS': {'weight': 105500.0, 'reps': 28},
#   'DUMBBELL_BICEPS_CURL': {'weight': 42000.0, 'reps': 12},
#   'INCLINE_DUMBBELL_BICEPS_CURL': {'weight': 175000.0, 'reps': 15},
#   'LEG_PRESS': {'weight': 172500.0, 'reps': 19},
#   'ONE_ARM_CABLE_LATERAL_RAISE': {'weight': 20000.0, 'reps': 11},
#   '_90_DEGREE_CABLE_EXTERNAL_ROTATION': {'weight': 15000.0, 'reps': 28}},
#  Timestamp('2025-07-08 00:00:00'): {'BARBELL_BULGARIAN_SPLIT_SQUAT': {'weight': 0.0,
#    'reps': 15},
#   'CABLE_ROW_STANDING': {'weight': 315000.0, 'reps': 60},
#   'CROSSED_ARMS_SIT_UP': {'weight': 0.0, 'reps': 30},
#   'SEATED_LEG_U': {'weight': 0.0, 'reps': 30},
#   'WIDE_GRIP_SEATED_CABLE_ROW': {'weight': 308000.0, 'reps': 25}},
#  Timestamp('2025-07-09 00:00:00'): {'CABLE_OVERHEAD_TRICEPS_EXTENSION': {'weight': 85000.0,
#    'reps': 22},
#   'CHEST_PRESS_WITH_BAND': {'weight': 231000.0, 'reps': 20},
#   'DUMBBELL_BENCH_PRESS': {'weight': 83000.0, 'reps': 20},
#   'DUMBBELL_BICEPS_CURL': {'weight': 44000.0, 'reps': 14},
#   'DUMBBELL_LATERAL_RAISE': {'weight': 40000.0, 'reps': 16},
#   'FARMERS_WALK': {'weight': 115000.0, 'reps': 4},
#   'LEG_PRESS': {'weight': 254000.0, 'reps': 15},
#   'ONE_ARM_CABLE_LATERAL_RAISE': {'weight': 27500.0, 'reps': 14},
#   '_90_DEGREE_CABLE_EXTERNAL_ROTATION': {'weight': 15000.0, 'reps': 30}},
#  Timestamp('2025-07-10 00:00:00'): {'CABLE_CRUNCH': {'weight': 140000.0,
#    'reps': 35},
#   'CABLE_EXTERNAL_ROTATION': {'weight': 22500.0, 'reps': 24},
#   'CABLE_INTERNAL_ROTATION': {'weight': 22500.0, 'reps': 24},
#   'CABLE_ROW_STANDING': {'weight': 240000.0, 'reps': 33},
#   'CROSSED_ARMS_SIT_UP': {'weight': 0.0, 'reps': 30},
#   'SEATED_CABLE_ROW': {'weight': 434000.0, 'reps': 32},
#   'SEATED_LEG_U': {'weight': 0.0, 'reps': 30}}}

# %%
# 定义颜色样式函数
def get_color_fmt(workbook, move, date):
    dates = movement_dates.get(move, [])
    if date not in dates:
        return None
    idx = dates.index(date)
    if idx > 0:
        delta = (date - dates[idx - 1]).days
        color = "#C6EFCE" if delta == 1 else "#BDD7EE"  # green or blue
    else:
        color = None
    if (latest_date - date).days > 3 and date == dates[-1]:
        color = "#F4CCCC"  # red
    fmt = workbook.add_format({"text_wrap": True, "valign": "top"})
    if color:
        fmt.set_bg_color(color)
    return fmt

# 生成 Excel 文件
output = excel_file_path
workbook = xlsxwriter.Workbook(output)
bold = workbook.add_format({"bold": True, "align": "center"})
wrap = workbook.add_format({"text_wrap": True, "valign": "top"})

months = [(2025, m) for m in range(1, 8)]

# Sheet 1: 横向日历
sheet1 = workbook.add_worksheet("按月横向排列")
col_base = 0
for y, m in months:
    cal = calendar.Calendar(firstweekday=6).monthdayscalendar(y, m)
    sheet1.write(0, col_base, f"{calendar.month_name[m]} {y}", bold)
    for i, wd in enumerate(["S", "M", "T", "W", "T", "F", "S"]):
        sheet1.write(1, col_base + i, wd, bold)
    for w_idx, week in enumerate(cal):
        for d_idx, day in enumerate(week):
            if day == 0:
                continue
            cur_date = datetime(y, m, day)
            sheet1.write(2 + w_idx * 4, col_base + d_idx, str(day), bold)
            movements = date_to_movements.get(cur_date, {})
            for r, (move, stat) in enumerate(movements.items()):
                txt = f"{move}\n{int(stat['weight'])}kg x {int(stat['reps'])}"
                fmt = get_color_fmt(workbook, move, cur_date) or wrap
                sheet1.write(3 + w_idx * 4 + r, col_base + d_idx, txt, fmt)
    for i in range(7):
        sheet1.set_column(col_base + i, col_base + i, 20)
    col_base += 8

# Sheet 2: 纵向日历
sheet2 = workbook.add_worksheet("按月纵向排列")
row_base = 0
for y, m in months:
    cal = calendar.Calendar(firstweekday=6).monthdayscalendar(y, m)
    sheet2.write(row_base, 0, f"{calendar.month_name[m]} {y}", bold)
    for i, wd in enumerate(["S", "M", "T", "W", "T", "F", "S"]):
        sheet2.write(row_base + 1, i, wd, bold)
    for w_idx, week in enumerate(cal):
        for d_idx, day in enumerate(week):
            if day == 0:
                continue
            cur_date = datetime(y, m, day)
            sheet2.write(row_base + 2 + w_idx * 4, d_idx, str(day), bold)
            movements = date_to_movements.get(cur_date, {})
            for r, (move, stat) in enumerate(movements.items()):
                txt = f"{move}\n{int(stat['weight'])}kg x {int(stat['reps'])}"
                fmt = get_color_fmt(workbook, move, cur_date) or wrap
                sheet2.write(row_base + 3 + w_idx * 4 + r, d_idx, txt, fmt)
    row_base += len(cal) * 4 + 5

# Sheet 3: 每月训练量按身体部位汇总
sheet3 = workbook.add_worksheet("每月训练总览")
summary = []
for y, m in months:
    start = datetime(y, m, 1)
    end = datetime(y, m, calendar.monthrange(y, m)[1])
    sub = df[(df["fmt_exercise_date"] >= start) & (df["fmt_exercise_date"] <= end)].copy()
    sub["bodypart"] = sub["fmt_movement"].map(movement_to_bodypart).fillna("OTHER")
    grp = sub.groupby("bodypart").agg(
        total_weight_kg=("weight", "sum"),
        total_reps=("repetition_count", "sum")
    ).reset_index()
    grp["month"] = f"{y}-{m:02d}"
    summary.append(grp)

monthly_summary = pd.concat(summary)
cols = ["month", "bodypart", "total_weight_kg", "total_reps"]
for i, col in enumerate(cols):
    sheet3.write(0, i, col, bold)
for r, row in enumerate(monthly_summary[cols].itertuples(index=False), start=1):
    for c, val in enumerate(row):
        sheet3.write(r, c, val)

workbook.close()
print(f"✅ 文件已生成：{output}")
